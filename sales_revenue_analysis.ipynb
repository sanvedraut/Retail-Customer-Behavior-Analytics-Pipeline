# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Analytics Environment Ready")
# Out:
# Analytics Environment Ready

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Install dependencies as needed:
#       2 # pip install kagglehub[pandas-datasets]
# ----> 3 import kagglehub
#       4 from kagglehub import KaggleDatasetAdapter
#       6 # Set the path to the file you'd like to load
#
# ModuleNotFoundError: No module named 'kagglehub'
